# %%
# !pip install -q mediapipe==0.10.1
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.8/33.8 MB 60.0 MB/s eta 0:00:00

# %%
# !wget -q https://storage.googleapis.com/mediapipe-models/hand_landmarker/hand_landmarker/float16/1/hand_landmarker.task

# %%
# !wget -q -O image.jpg https://i.kinja-img.com/gawker-media/image/upload/s--A99mnFf8--/c_fill,fl_progressive,g_center,h_900,q_80,w_1600/17r2nhmg9n26mjpg.jpg

import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread("image.jpg")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=1600x900 at 0x7ED338159E70>

# %%
import cv2
import mediapipe as mp

# Load the image
image = cv2.imread("image.jpg")

# Initialize Mediapipe HandLandmark model
mp_drawing = mp.solutions.drawing_utils
mp_hands = mp.solutions.hands

# Detect hand landmarks in the image
with mp_hands.Hands(static_image_mode=True, max_num_hands=20) as hands:
    # Convert the image to RGB before processing
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = hands.process(image_rgb)

    # Check if hands were detected
    if results.multi_hand_landmarks:
        # Get the count of detected hands
        hand_count = len(results.multi_hand_landmarks)
        print("Number of hands:", hand_count)

        # Draw landmarks on the image for each detected hand
        for hand_landmarks in results.multi_hand_landmarks:
            mp_drawing.draw_landmarks(
                image, hand_landmarks, mp_hands.HAND_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2)
            )
    else:
        print("No hands detected in the image.")

# Display the image with landmarks
cv2_imshow( image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Number of hands: 3
# <PIL.Image.Image image mode=RGB size=1600x900 at 0x7ED28DE2B580>
